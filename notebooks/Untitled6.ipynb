# %%
import matplotlib.pyplot as plt
from PIL import Image
import os
import sys
import random
import math
import re
import time
import numpy as np
def ans_cut(N):
    a=Image.open('/afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/ilovepdf_images-extracted/img'+N+'.jpg')
    pic=np.zeros((50,60,6))
    n=6
    m=0
    m1=2
    pic[:,:,0]=np.array(a)[225+m:275+m,15+n:75+n,0]
    pic[:,:,3]=np.array(a)[298+m1:348+m1,15+n:75+n,0]
    pic[:,:,1]=np.array(a)[225+m:275+m,125+n:185+n,0]
    pic[:,:,4]=np.array(a)[298+m1:348+m1,125+n:185+n,0]
    pic[:,:,2]=np.array(a)[225+m:275+m,235+n:295+n,0]
    pic[:,:,5]=np.array(a)[298+m1:348+m1,235+n:295+n,0]
    p=np.array(a)[100:150,110:170,0]
    for i in range (0,6):
        plt.subplot(2,3,i+1)
        plt.imshow(pic[:,:,i])
    return p,pic,a
p,pic,a=ans_cut('35')

# %%
from con1 import train_cov
#from an import ans_cut
import numpy as np
#p,pic,a=ans_cut('43')
from forw import forward,compare
from gen_mix_m import mix_m
pic1=mix_m(1,pic)
for i in range (0,6):
    plt.subplot(2,3,i+1)
    plt.imshow(pic1[:,:,i],cmap='gray')
i=0
W1=np.zeros((10,10,1,3,50))
W2=np.zeros((25,25,3,6,50))
E1=np.zeros((50,6))
E2=np.zeros((50,6))
m=[0,3,4,5]
while i<50:
    w1,w2,Num=train_cov(pic[:,:,m])
    if Num==1:
        W1[:,:,:,:,i]=w1
        W2[:,:,:,:,i]=w2
        I1,II2=forward(p,pic1,w1,w2)
        E1[i,:],E2[i,:]=compare(I1,II2)
        i+=1
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0628 19:55:28.225322 140462080051008 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/con1.py:21: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0628 19:55:28.466784 140462080051008 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/con1.py:27: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0628 19:55:28.737716 140462080051008 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/convo1.py:11: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0628 19:55:28.802561 140462080051008 deprecation.py:506] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/convo1.py:38: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0628 19:55:28.816331 140462080051008 deprecation.py:323] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/con1.py:49: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0628 19:55:29.106877 140462080051008 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/con1.py:50: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0628 19:55:29.319214 140462080051008 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/con1.py:59: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# W0628 19:55:29.320940 140462080051008 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/con1.py:69: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# Step 1, Minibatch Loss= 173241.9531, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 79860.0234, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 73449.0781, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 44031.1484, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 75774.5156, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 7633.5474, Train Accuracy= 0.000
# Step 9, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 218579.1562, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 110519.5000, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 15055.7334, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 43406.7734, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 25538.0391, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 6869.1162, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 15631.2783, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 14442.6113, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 8515.6602, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 6385.3760, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 6248.9258, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 4689.8286, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 9536.9189, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 3817.0996, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 125.8145, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 2544.8108, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 7704.0283, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 2725.0513, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 2621.2144, Train Accuracy= 0.000
# Step 9, Minibatch Loss= 9592.6113, Train Accuracy= 0.000
# Step 10, Minibatch Loss= 5561.4805, Train Accuracy= 0.000
# Step 11, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 3432.5410, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 2508.7949, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 1386.7930, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 20354.6094, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 46588.7969, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 17802.3203, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 6, Minibatch Loss= 2666.1641, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 24114.8086, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 449.0547, Train Accuracy= 0.000
# Step 9, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 119011.5312, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 69200.0000, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 60925.1562, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 132572.4844, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 109754.8906, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 119.4043, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 118027.6406, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 6, Minibatch Loss= 69772.1797, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 58184.9766, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 94519.2812, Train Accuracy= 0.000
# Step 9, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 11070.5078, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 1011.1523, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 95628.3906, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 566.5195, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 74226.1719, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 60901.3203, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 47081.9883, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 32652.1211, Train Accuracy= 0.000
# Step 9, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 16494.5215, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 11716.1807, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 51455.6016, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 5691.7422, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 233214.2031, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 73407.6328, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 173281.7500, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 148660.5781, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 188770.6562, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 80518.1953, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 49838.7617, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 123359.8672, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 12099.9766, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 194907.2500, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 41304.5391, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 282.9340, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 1263.3447, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 1354.1090, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 1278.3685, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 1077.4919, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 23817.5703, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 449.5421, Train Accuracy= 0.000
# Step 9, Minibatch Loss= 17231.4375, Train Accuracy= 0.000
# Step 10, Minibatch Loss= 12791.2998, Train Accuracy= 0.000
# Step 11, Minibatch Loss= 7950.9653, Train Accuracy= 0.000
# Step 12, Minibatch Loss= 5353.4165, Train Accuracy= 0.000
# Step 13, Minibatch Loss= 4836.2007, Train Accuracy= 0.000
# Step 14, Minibatch Loss= 4085.8513, Train Accuracy= 0.000
# Step 15, Minibatch Loss= 547.4103, Train Accuracy= 0.000
# Step 16, Minibatch Loss= 3081.4951, Train Accuracy= 0.000
# Step 17, Minibatch Loss= 489.2798, Train Accuracy= 0.000
# Step 18, Minibatch Loss= 1082.5825, Train Accuracy= 0.000
# Step 19, Minibatch Loss= 825.5293, Train Accuracy= 0.000
# Step 20, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 48181.3516, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 2460.1455, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 6, Minibatch Loss= 110069.9688, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 29912.1133, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 25247.9727, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 20693.1426, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 30143.5879, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 15390.0566, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 143960.5000, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 118588.0859, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 106153.7969, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 119733.0625, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 165759.2344, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 46623.6836, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 53488.6406, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 143989.1094, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 110238.0703, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 61574.5547, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 2145.5000, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 123709.1094, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 88867.1875, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 52314.0234, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 36842.2812, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 311925.4062, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 267036.9375, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 25859.4199, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 176844.3125, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 40403.3320, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 91626.9219, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 66669.0000, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 59254.0898, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 14788.4639, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 13858.3750, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 91352.6875, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 6, Minibatch Loss= 1045.8093, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 66731.6953, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 6, Minibatch Loss= 12453.6152, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 56416.0977, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 13452.5293, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 871.1113, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 3324.1614, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 6, Minibatch Loss= 3939.6699, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 765.3516, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 4029.9214, Train Accuracy= 0.000
# Step 9, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 30006.5234, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 42944.4375, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 2776.0117, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 5810.3145, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 131351.9688, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 115531.6719, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 202353.2500, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 182674.3125, Train Accuracy= 0.000
# Step 9, Minibatch Loss= 370.3008, Train Accuracy= 0.000
# Step 10, Minibatch Loss= 152413.4688, Train Accuracy= 0.000
# Step 11, Minibatch Loss= 138247.1250, Train Accuracy= 0.000
# Step 12, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 3088.8359, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 31703.9336, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 15374.6367, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 15253.3223, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 14385.9180, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 39667.4648, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 32858.8086, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 36.6025, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 827.0862, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 18976.8105, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 33544.2344, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 23401.6016, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 27830.6152, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 1750.8635, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 2720.9727, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 19908.0352, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 2457.7305, Train Accuracy= 0.000
# Step 9, Minibatch Loss= 15217.9014, Train Accuracy= 0.000
# Step 10, Minibatch Loss= 11027.6553, Train Accuracy= 0.000
# Step 11, Minibatch Loss= 992.9761, Train Accuracy= 0.000
# Step 12, Minibatch Loss= 13273.1836, Train Accuracy= 0.000
# Step 13, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 40868.7109, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 3618.1450, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 12800.7344, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 2006.8047, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 7443.5469, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 75805.3750, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 53834.1641, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 15632.8672, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 16649.2344, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 22843.6406, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 15598.4414, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 9345.2559, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 3148.6055, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 752.5474, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 213423.2031, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 173075.2188, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 133476.2969, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 148295.9844, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 134648.5000, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 75007.9297, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 10286.2832, Train Accuracy= 0.000
# Step 9, Minibatch Loss= 10736.7695, Train Accuracy= 0.000
# Step 10, Minibatch Loss= 30883.0234, Train Accuracy= 0.000
# Step 11, Minibatch Loss= 10085.7139, Train Accuracy= 0.000
# Step 12, Minibatch Loss= 3849.7969, Train Accuracy= 0.000
# Step 13, Minibatch Loss= 60887.4453, Train Accuracy= 0.000
# Step 14, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 11101.4795, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 36137.1836, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 77406.2031, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 11337.5674, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 99102.7188, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 73773.4453, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 48251.2852, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 7001.5107, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 54368.8164, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 33700.7617, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 83834.0469, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 5682.0664, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 1724.5107, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 3378.4541, Train Accuracy= 0.000
# Step 9, Minibatch Loss= 4522.0361, Train Accuracy= 0.000
# Step 10, Minibatch Loss= 60451.0078, Train Accuracy= 0.000
# Step 11, Minibatch Loss= 36773.0078, Train Accuracy= 0.000
# Step 12, Minibatch Loss= 42424.0508, Train Accuracy= 0.000
# Step 13, Minibatch Loss= 3388.4341, Train Accuracy= 0.000
# Step 14, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 18756.3125, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 16237.1367, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 91176.7500, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 14224.3242, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 48889.3945, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 6011.8091, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 25754.0332, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 13202.9111, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 136706.4688, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 27860.9844, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 45440.5703, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 9704.5430, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 8882.2188, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 35579.5156, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 43891.6953, Train Accuracy= 0.000
# Step 9, Minibatch Loss= 0.0000, Train Accuracy= 1.000
