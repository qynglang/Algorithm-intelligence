# %%
import numpy as np
import matplotlib.pyplot as plt
data=np.load('data.npy')
for i in range (0,16):
    plt.subplot(4,4,i+1)
    plt.imshow(data[:,:,i,12])

# %%
n=12
from con1 import train_cov
import numpy as np
import matplotlib.pyplot as plt
data=np.load('data.npy')
#from loadone1 import load_sample as load
w1=np.zeros((5,5,1,3))
w2=np.zeros((5,5,3,6))
m=np.array([0,1,2])
#M12,a12=load(data[:,:,m,12])
w1[:,:,:,:],w2[:,:,:,:]=train_cov(data[:,:,m,n],300,3,8)
from fcon import train_fcon
answer=np.load('ans.npy')
train_fcon(data[:,:,:,n].reshape(28,28,16),w1[:,:,:,:].reshape(5,5,1,3,1),w2[:,:,:,:].reshape(5,5,3,6,1),answer[n],50,3,8)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0630 16:53:20.495175 140297918564160 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/Untitled Folder/con1.py:21: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0630 16:53:20.512027 140297918564160 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/Untitled Folder/con1.py:27: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0630 16:53:20.562829 140297918564160 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/Untitled Folder/convo.py:11: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0630 16:53:20.570595 140297918564160 deprecation.py:506] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/Untitled Folder/convo.py:38: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0630 16:53:20.586067 140297918564160 deprecation.py:323] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/Untitled Folder/con1.py:49: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0630 16:53:20.609914 140297918564160 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/Untitled Folder/con1.py:50: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0630 16:53:20.762207 140297918564160 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/Untitled Folder/con1.py:59: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# W0630 16:53:20.768672 140297918564160 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/Untitled Folder/con1.py:69: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a0eb14876015> in <module>
#       9 m=np.array([0,1,2])
#      10 #M12,a12=load(data[:,:,m,12])
# ---> 11 w1[:,:,:,:],w2[:,:,:,:]=train_cov(data[:,:,m,n],300,3,8)
#      12 from fcon import train_fcon
#      13 answer=np.load('ans.npy')
#
# ~/Downloads/experiment/Untitled Folder/con1.py in train_cov(A, n, a, bs)
#      70
#      71         # Run the initializer
# ---> 72         sess.run(init)
#      73         #batch_x1, batch_y1 = load(A)
#      74         #batch_x2, batch_y2 = load(A)
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
A=np.zeros((8,2,50))
B=np.zeros((8,2,50))
N=np.zeros(50)
for i in range (0,50):
    n=12
    from con1 import train_cov
    import numpy as np
    import matplotlib.pyplot as plt
    data=np.load('data.npy')
    #from loadone1 import load_sample as load
    w1=np.zeros((5,5,1,3))
    w2=np.zeros((5,5,3,6))
    m=np.array([0,1,2])
    #M12,a12=load(data[:,:,m,12])
    w1[:,:,:,:],w2[:,:,:,:],Num=train_cov(data[:,:,m,n],300,3,8)
    if Num==1:
        from fcon import train_fcon
        answer=np.load('ans.npy')
        A[:,:,i],B[:,:,i],N[i]=train_fcon(data[:,:,:,n].reshape(28,28,16),w1[:,:,:,:].reshape(5,5,1,3,1),w2[:,:,:,:].reshape(5,5,3,6,1),answer[n],50,3,8)
# Out:
# Step 1, Minibatch Loss= 2018.5594, Train Accuracy= 0.250
# Step 2, Minibatch Loss= 59.8402, Train Accuracy= 0.875
# Step 3, Minibatch Loss= 252.8752, Train Accuracy= 0.750
# Step 4, Minibatch Loss= 25.8084, Train Accuracy= 0.875
# Step 5, Minibatch Loss= 6473.0752, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 3572.2837, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 2174.0815, Train Accuracy= 0.125
# Step 8, Minibatch Loss= 4901.7896, Train Accuracy= 0.000
# Step 9, Minibatch Loss= 101.6178, Train Accuracy= 0.875
# Step 10, Minibatch Loss= 4620.0923, Train Accuracy= 0.000
# Step 11, Minibatch Loss= 1785.0078, Train Accuracy= 0.125
# Step 12, Minibatch Loss= 4140.3667, Train Accuracy= 0.000
# Step 13, Minibatch Loss= 699.5509, Train Accuracy= 0.250
# Step 14, Minibatch Loss= 834.3237, Train Accuracy= 0.500
# Step 15, Minibatch Loss= 467.8238, Train Accuracy= 0.625
# Step 16, Minibatch Loss= 1157.6843, Train Accuracy= 0.375
# Step 17, Minibatch Loss= 2286.7959, Train Accuracy= 0.000
# Step 18, Minibatch Loss= 164.1576, Train Accuracy= 0.750
# Step 19, Minibatch Loss= 632.5468, Train Accuracy= 0.375
# Step 20, Minibatch Loss= 718.8865, Train Accuracy= 0.375
# Step 21, Minibatch Loss= 527.9723, Train Accuracy= 0.500
# Step 22, Minibatch Loss= 804.3099, Train Accuracy= 0.250
# Step 23, Minibatch Loss= 180.3049, Train Accuracy= 0.750
# Step 24, Minibatch Loss= 1214.4930, Train Accuracy= 0.125
# Step 25, Minibatch Loss= 1650.4517, Train Accuracy= 0.000
# Step 26, Minibatch Loss= 4134.6831, Train Accuracy= 0.000
# Step 27, Minibatch Loss= 1644.5371, Train Accuracy= 0.250
# Step 28, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 1170330.8750, Train Accuracy= 0.500
# Step 3, Minibatch Loss= 1199856.8750, Train Accuracy= 0.500
# Step 4, Minibatch Loss= 1347416.7500, Train Accuracy= 0.125
# Step 5, Minibatch Loss= 320266.7812, Train Accuracy= 0.500
# Step 6, Minibatch Loss= 252899.6562, Train Accuracy= 0.500
# Step 7, Minibatch Loss= 240179.4688, Train Accuracy= 0.625
# Step 8, Minibatch Loss= 18198.7500, Train Accuracy= 0.875
# Step 9, Minibatch Loss= 166661.0312, Train Accuracy= 0.500
# Step 10, Minibatch Loss= 221238.8125, Train Accuracy= 0.750
# Step 11, Minibatch Loss= 163024.8125, Train Accuracy= 0.500
# Step 12, Minibatch Loss= 45560.4062, Train Accuracy= 0.875
# Step 13, Minibatch Loss= 9516.7188, Train Accuracy= 0.875
# Step 14, Minibatch Loss= 53621.5625, Train Accuracy= 0.750
# Step 15, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Testing Accuracy: 0.5
# Step 1, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 4, Minibatch Loss= 6538.4258, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 16692.6875, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 13277.0469, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 200.6660, Train Accuracy= 0.875
# Step 8, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 731676.2500, Train Accuracy= 0.375
# Step 2, Minibatch Loss= 385933.5625, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 415596.0938, Train Accuracy= 0.750
# Step 4, Minibatch Loss= 1542219.2500, Train Accuracy= 0.375
# Step 5, Minibatch Loss= 367702.2500, Train Accuracy= 0.875
# Step 6, Minibatch Loss= 1195021.0000, Train Accuracy= 0.500
# Step 7, Minibatch Loss= 1368817.5000, Train Accuracy= 0.375
# Step 8, Minibatch Loss= 680639.5000, Train Accuracy= 0.500
# Step 9, Minibatch Loss= 363487.6250, Train Accuracy= 0.375
# Step 10, Minibatch Loss= 38740.1562, Train Accuracy= 0.875
# Step 11, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Testing Accuracy: 0.125
# Step 1, Minibatch Loss= 5609.7378, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 4680.1787, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 3750.8069, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 5, Minibatch Loss= 2012.1735, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 1934.4153, Train Accuracy= 0.000
# Step 7, Minibatch Loss= 753.4172, Train Accuracy= 0.125
# Step 8, Minibatch Loss= 318.5867, Train Accuracy= 0.375
# Step 9, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 216348.9062, Train Accuracy= 0.750
# Step 2, Minibatch Loss= 331351.9375, Train Accuracy= 0.625
# Step 3, Minibatch Loss= 332500.6250, Train Accuracy= 0.500
# Step 4, Minibatch Loss= 253289.8906, Train Accuracy= 0.125
# Step 5, Minibatch Loss= 6720.3438, Train Accuracy= 0.750
# Step 6, Minibatch Loss= 4874.2031, Train Accuracy= 0.875
# Step 7, Minibatch Loss= 39268.0000, Train Accuracy= 0.625
# Step 8, Minibatch Loss= 169554.7969, Train Accuracy= 0.625
# Step 9, Minibatch Loss= 152125.4375, Train Accuracy= 0.500
# Step 10, Minibatch Loss= 18471.0156, Train Accuracy= 0.875
# Step 11, Minibatch Loss= 43410.8281, Train Accuracy= 0.750
# Step 12, Minibatch Loss= 56481.2500, Train Accuracy= 0.625
# Step 13, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Testing Accuracy: 0.375
# Step 1, Minibatch Loss= 92681.1250, Train Accuracy= 0.000
# Step 2, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 3, Minibatch Loss= 71696.7969, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 34173.4883, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 26030.2812, Train Accuracy= 0.000
# Step 6, Minibatch Loss= 192.8967, Train Accuracy= 0.875
# Step 7, Minibatch Loss= 36379.5938, Train Accuracy= 0.000
# Step 8, Minibatch Loss= 2318.6467, Train Accuracy= 0.500
# Step 9, Minibatch Loss= 6479.6523, Train Accuracy= 0.000
# Step 10, Minibatch Loss= 26425.8789, Train Accuracy= 0.000
# Step 11, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Step 1, Minibatch Loss= 1108310.0000, Train Accuracy= 0.875
# Step 2, Minibatch Loss= 2753687.5000, Train Accuracy= 0.500
# Step 3, Minibatch Loss= 1044551.0625, Train Accuracy= 0.500
# Step 4, Minibatch Loss= 2412945.0000, Train Accuracy= 0.750
# Step 5, Minibatch Loss= 7962543.5000, Train Accuracy= 0.375
# Step 6, Minibatch Loss= 8614087.0000, Train Accuracy= 0.250
# Step 7, Minibatch Loss= 2690642.0000, Train Accuracy= 0.750
# Step 8, Minibatch Loss= 3652220.5000, Train Accuracy= 0.625
# Step 9, Minibatch Loss= 4268899.0000, Train Accuracy= 0.375
# Step 10, Minibatch Loss= 2295310.5000, Train Accuracy= 0.250
# Step 11, Minibatch Loss= 0.0000, Train Accuracy= 1.000
# Testing Accuracy: 0.125
# Step 1, Minibatch Loss= 160.3486, Train Accuracy= 0.625
# Step 2, Minibatch Loss= 4414.1816, Train Accuracy= 0.000
# Step 3, Minibatch Loss= 3119.4731, Train Accuracy= 0.000
# Step 4, Minibatch Loss= 2729.8608, Train Accuracy= 0.000
# Step 5, Minibatch Loss= 108.6942, Train Accuracy= 0.625
# Step 6, Minibatch Loss= 7.7303, Train Accuracy= 0.875
# Step 7, Minibatch Loss= 45.6855, Train Accuracy= 0.875
# Step 8, Minibatch Loss= 1434.2509, Train Accuracy= 0.125
# Step 9, Minibatch Loss= 8.5222, Train Accuracy= 0.875
# Step 10, Minibatch Loss= 1567.6356, Train Accuracy= 0.000
# Step 11, Minibatch Loss= 966.9287, Train Accuracy= 0.000
# Step 12, Minibatch Loss= 50.1352, Train Accuracy= 0.750
# Step 13, Minibatch Loss= 358.6091, Train Accuracy= 0.375
# Step 14, Minibatch Loss= 105.6035, Train Accuracy= 0.750
# Step 15, Minibatch Loss= 238.3742, Train Accuracy= 0.625
# Step 16, Minibatch Loss= 1535.0027, Train Accuracy= 0.000
# Step 17, Minibatch Loss= 230.6730, Train Accuracy= 0.625
# Step 18, Minibatch Loss= 1214.6006, Train Accuracy= 0.125
# Step 19, Minibatch Loss= 676.2076, Train Accuracy= 0.125
# Step 20, Minibatch Loss= 1045.1455, Train Accuracy= 0.250
# Step 21, Minibatch Loss= 35.4080, Train Accuracy= 0.750
# Step 22, Minibatch Loss= 21.8602, Train Accuracy= 0.875
# Step 23, Minibatch Loss= 815.0120, Train Accuracy= 0.125
# Step 24, Minibatch Loss= 692.4980, Train Accuracy= 0.250
# Step 25, Minibatch Loss= 1098.9478, Train Accuracy= 0.000
# Step 26, Minibatch Loss= 0.0000, Train Accuracy= 1.000
