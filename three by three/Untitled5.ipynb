# %%
from run_r_error import foward_error

# %%
foward_error(0,[0,3,6,9,10,13,14,15],7,'9_0')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0726 18:53:54.215015 140253938042688 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/Untitled Folder/con1.py:21: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0726 18:53:54.219334 140253938042688 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/Untitled Folder/con1.py:27: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0726 18:53:54.273952 140253938042688 deprecation_wrapper.py:119] From /afs/inf.ed.ac.uk/user/s18/s1883226/Downloads/experiment/Untitled Folder/convo.py:11: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
a=[1,1,1]
import numpy as np
b=np.where(np.array(a)==1)

# %%
b[0].size
# Out:
# 3
